# %%
#Import basic scientific python libs
import pandas as pd
import numpy as np
import datetime
import re

# %%
# artist = pd.read_csv("artist.csv",nrows = 500)
artist = pd.read_csv("artist.csv",low_memory=False)

# %%
# artist = pd.read_csv("testdata.csv")

# %%
artist.shape
# Out:
# (96303, 147)

# %%
artist.head()
# Out:
#                                               URI  \
# 0                                             URI
# 1                                             URI
# 2             http://www.w3.org/2002/07/owl#Thing
# 3  http://dbpedia.org/resource/Marius_Reksj%C3%B8
# 4     http://dbpedia.org/resource/Marius_de_Vries
#
#                                rdf-schema#label  \
# 0    http://www.w3.org/2000/01/rdf-schema#label
# 1                            rdf-schema#Literal
# 2  http://www.w3.org/2000/01/rdf-schema#Literal
# 3                                 Marius Reksjø
# 4                               Marius de Vries
#
#                                   rdf-schema#comment  \
# 0       http://www.w3.org/2000/01/rdf-schema#comment
# 1                                 rdf-schema#Literal
# 2       http://www.w3.org/2000/01/rdf-schema#Literal
# 3  Marius Julian Reksjø (born 3 October 1973 in H...
# 4  Marius de Vries (born 1961) is an English musi...
#
#                                       height  \
# 0  http://dbpedia.org/ontology/Person/height
# 1                                 centimetre
# 2     http://dbpedia.org/datatype/centimetre
# 3                                        NaN
# 4                                        NaN
#
#                                       weight  \
# 0  http://dbpedia.org/ontology/Person/weight
# 1                                   kilogram
# 2       http://dbpedia.org/datatype/kilogram
# 3                                        NaN
# 4                                        NaN
#
#                                     runtime  \
# 0  http://dbpedia.org/ontology/Work/runtime
# 1                                    minute
# 2        http://dbpedia.org/datatype/minute
# 3                                       NaN
# 4                                       NaN
#
#                                activeYearsEndYear  \
# 0  http://dbpedia.org/ontology/activeYearsEndYear
# 1                                 XMLSchema#gYear
# 2          http://www.w3.org/2001/XMLSchema#gYear
# 3                                             NaN
# 4                                             NaN
#
#                                activeYearsStartYear  \
# 0  http://dbpedia.org/ontology/activeYearsStartYear
# 1                                   XMLSchema#gYear
# 2            http://www.w3.org/2001/XMLSchema#gYear
# 3                                               NaN
# 4                                               NaN
#
#                                      alias  \
# 0        http://dbpedia.org/ontology/alias
# 1                         XMLSchema#string
# 2  http://www.w3.org/2001/XMLSchema#string
# 3                     Reksjø Marius Julian
# 4                                      NaN
#
#                            almaMater_label  ...  \
# 0    http://dbpedia.org/ontology/almaMater  ...
# 1                         XMLSchema#string  ...
# 2  http://www.w3.org/2001/XMLSchema#string  ...
# 3                                      NaN  ...
# 4                                      NaN  ...
#
#                                    description  \
# 0  http://purl.org/dc/elements/1.1/description
# 1                             XMLSchema#string
# 2      http://www.w3.org/2001/XMLSchema#string
# 3                       Norwegian jazz bassist
# 4                               music producer
#
#                                      point  \
# 0       http://www.georss.org/georss/point
# 1                         XMLSchema#string
# 2  http://www.w3.org/2001/XMLSchema#string
# 3                                      NaN
# 4                                      NaN
#
#                          22-rdf-syntax-ns#type_label  \
# 0    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 1                                   XMLSchema#string
# 2            http://www.w3.org/2001/XMLSchema#string
# 3  {agent|artist|musical artist|person|owl#Thing|...
# 4  {agent|artist|musical artist|person|owl#Thing|...
#
#                                22-rdf-syntax-ns#type  \
# 0    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 1                                   rdf-schema#Class
# 2         http://www.w3.org/2000/01/rdf-schema#Class
# 3  {http://dbpedia.org/ontology/Agent|http://dbpe...
# 4  {http://dbpedia.org/ontology/Agent|http://dbpe...
#
#                           owl#sameAs_label  \
# 0     http://www.w3.org/2002/07/owl#sameAs
# 1                         XMLSchema#string
# 2  http://www.w3.org/2001/XMLSchema#string
# 3                    {m.0tdm4cy|m.0n5vc3b}
# 4      {m.0bv5sf5|Marius_de_Vries|Q539155}
#
#                                           owl#sameAs  \
# 0               http://www.w3.org/2002/07/owl#sameAs
# 1                                          owl#Thing
# 2                http://www.w3.org/2002/07/owl#Thing
# 3  {http://rdf.freebase.com/ns/m.0tdm4cy|http://r...
# 4  {http://rdf.freebase.com/ns/m.0bv5sf5|http://d...
#
#                                  wgs84_pos#lat  \
# 0  http://www.w3.org/2003/01/geo/wgs84_pos#lat
# 1                              XMLSchema#float
# 2       http://www.w3.org/2001/XMLSchema#float
# 3                                          NaN
# 4                                          NaN
#
#                                  wgs84_pos#long  \
# 0  http://www.w3.org/2003/01/geo/wgs84_pos#long
# 1                               XMLSchema#float
# 2        http://www.w3.org/2001/XMLSchema#float
# 3                                           NaN
# 4                                           NaN
#
#                             core#subject_label  \
# 0  http://www.w3.org/2004/02/skos/core#subject
# 1                             XMLSchema#string
# 2      http://www.w3.org/2001/XMLSchema#string
# 3                                          NaN
# 4                                          NaN
#
#                                   core#subject
# 0  http://www.w3.org/2004/02/skos/core#subject
# 1                                    owl#Thing
# 2          http://www.w3.org/2002/07/owl#Thing
# 3                                          NaN
# 4                                          NaN
#
# [5 rows x 147 columns]

# %%
#select col
new_artic = artist.loc[:,['rdf-schema#label','birthDate','birthPlace_label','deathDate','field_label',
              'genre_label','instrument_label','thumbnail','wikiPageID','description']]

# %%
new_artic.head()
# Out:
#                                rdf-schema#label  \
# 0    http://www.w3.org/2000/01/rdf-schema#label
# 1                            rdf-schema#Literal
# 2  http://www.w3.org/2000/01/rdf-schema#Literal
# 3                                 Marius Reksjø
# 4                               Marius de Vries
#
#                                birthDate  \
# 0  http://dbpedia.org/ontology/birthDate
# 1                         XMLSchema#date
# 2  http://www.w3.org/2001/XMLSchema#date
# 3                             1973-10-03
# 4              1961-01-01T00:00:00+02:00
#
#                           birthPlace_label  \
# 0   http://dbpedia.org/ontology/birthPlace
# 1                         XMLSchema#string
# 2  http://www.w3.org/2001/XMLSchema#string
# 3                 {Norway|Horten|Vestfold}
# 4                                   London
#
#                                deathDate  \
# 0  http://dbpedia.org/ontology/deathDate
# 1                         XMLSchema#date
# 2  http://www.w3.org/2001/XMLSchema#date
# 3                                    NaN
# 4                                    NaN
#
#                                field_label  \
# 0        http://dbpedia.org/ontology/field
# 1                         XMLSchema#string
# 2  http://www.w3.org/2001/XMLSchema#string
# 3                                      NaN
# 4                                      NaN
#
#                                genre_label  \
# 0        http://dbpedia.org/ontology/genre
# 1                         XMLSchema#string
# 2  http://www.w3.org/2001/XMLSchema#string
# 3                                     Jazz
# 4                                      NaN
#
#                           instrument_label  \
# 0   http://dbpedia.org/ontology/instrument
# 1                         XMLSchema#string
# 2  http://www.w3.org/2001/XMLSchema#string
# 3                              Double bass
# 4                                      NaN
#
#                                thumbnail  \
# 0  http://dbpedia.org/ontology/thumbnail
# 1                              owl#Thing
# 2    http://www.w3.org/2002/07/owl#Thing
# 3                                    NaN
# 4                                    NaN
#
#                                  wikiPageID  \
# 0    http://dbpedia.org/ontology/wikiPageID
# 1                         XMLSchema#integer
# 2  http://www.w3.org/2001/XMLSchema#integer
# 3                                  37301663
# 4                                  30865730
#
#                                    description
# 0  http://purl.org/dc/elements/1.1/description
# 1                             XMLSchema#string
# 2      http://www.w3.org/2001/XMLSchema#string
# 3                       Norwegian jazz bassist
# 4                               music producer

# %%
#select row
new_artic = new_artic.iloc[3:,]

# %%
new_artic.head()
# Out:
#   rdf-schema#label                  birthDate          birthPlace_label  \
# 3    Marius Reksjø                 1973-10-03  {Norway|Horten|Vestfold}
# 4  Marius de Vries  1961-01-01T00:00:00+02:00                    London
# 5  Marius de Zayas  1880-01-01T00:00:00+02:00                  Veracruz
# 6  Mariusz Adamski                 1974-01-10                       NaN
# 7     Mariusz Duda                 1975-09-25                       NaN
#
#                    deathDate                      field_label  \
# 3                        NaN                              NaN
# 4                        NaN                              NaN
# 5  1961-01-01T00:00:00+02:00                              Art
# 6                        NaN  {Author|Air-to-air photography}
# 7                        NaN                              NaN
#
#                             genre_label  \
# 3                                  Jazz
# 4                                   NaN
# 5                                   NaN
# 6                                   NaN
# 7  {Progressive metal|Progressive rock}
#
#                                     instrument_label  \
# 3                                        Double bass
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  {Bass guitar|Drum kit|Percussion instrument|Ke...
#
#                                            thumbnail wikiPageID  \
# 3                                                NaN   37301663
# 4                                                NaN   30865730
# 5  http://commons.wikimedia.org/wiki/Special:File...   12891104
# 6                                                NaN   27473093
# 7  http://commons.wikimedia.org/wiki/Special:File...   13101869
#
#               description
# 3  Norwegian jazz bassist
# 4          music producer
# 5          Mexican artist
# 6     Polish photographer
# 7         Polish musician

# %%
new_artic = new_artic.reindex()

# %%
new_artic.head()
# Out:
#   rdf-schema#label                  birthDate          birthPlace_label  \
# 3    Marius Reksjø                 1973-10-03  {Norway|Horten|Vestfold}
# 4  Marius de Vries  1961-01-01T00:00:00+02:00                    London
# 5  Marius de Zayas  1880-01-01T00:00:00+02:00                  Veracruz
# 6  Mariusz Adamski                 1974-01-10                       NaN
# 7     Mariusz Duda                 1975-09-25                       NaN
#
#                    deathDate                      field_label  \
# 3                        NaN                              NaN
# 4                        NaN                              NaN
# 5  1961-01-01T00:00:00+02:00                              Art
# 6                        NaN  {Author|Air-to-air photography}
# 7                        NaN                              NaN
#
#                             genre_label  \
# 3                                  Jazz
# 4                                   NaN
# 5                                   NaN
# 6                                   NaN
# 7  {Progressive metal|Progressive rock}
#
#                                     instrument_label  \
# 3                                        Double bass
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  {Bass guitar|Drum kit|Percussion instrument|Ke...
#
#                                            thumbnail wikiPageID  \
# 3                                                NaN   37301663
# 4                                                NaN   30865730
# 5  http://commons.wikimedia.org/wiki/Special:File...   12891104
# 6                                                NaN   27473093
# 7  http://commons.wikimedia.org/wiki/Special:File...   13101869
#
#               description
# 3  Norwegian jazz bassist
# 4          music producer
# 5          Mexican artist
# 6     Polish photographer
# 7         Polish musician

# %%
new_artic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96300 entries, 3 to 96302
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   rdf-schema#label  95845 non-null  object
#  1   birthDate         80641 non-null  object
#  2   birthPlace_label  56428 non-null  object
#  3   deathDate         29148 non-null  object
#  4   field_label       6456 non-null   object
#  5   genre_label       41988 non-null  object
#  6   instrument_label  22217 non-null  object
#  7   thumbnail         39724 non-null  object
#  8   wikiPageID        95845 non-null  object
#  9   description       89610 non-null  object
# dtypes: object(10)
# memory usage: 7.3+ MB

# %%
type(new_artic["birthDate"])
# Out:
# pandas.core.series.Series

# %%
test = "19990221"
test = test[6:8]

# %%
test
# Out:
# '21'

# %%
df = pd.DataFrame(new_artic)

# %%
# Code to parse data
# Detail Auditing and cleansing will made in next part
# in this part,only ID,Open and Close will be remade to match the format

df.dtypes
time = 0
def check(name,dtype):
    result = True
    for row in df[name]:
        #print（row）
        result = isinstance(row, dtype)
        if result == False:
            result = name +": "+ str(result) + " wrong type: " + str(type(row)) + " Example: "+ str(row)
            return result
#             print(df[name],row)
    result = name +": "+ str(result)
    return result
def checkRow(name,dtype):
    result = True
    for row in df[name]:
        #print（row）
        result = isinstance(row, dtype)
        if result == False:
            return row
#             print(df[name],row)
    return result
def timemaker(name):
    temp = []
    time = []
    for row in df[name]:
        if isinstance(row, int)== True:
            print("error date as float: " + str(row))
        elif pd.isnull(row)!=True: 
#             if len(str(row))!=10:
                #print("len error: " + str(row))
            row = re.sub(r'\D','',row)
            if len(str(row))==8:
                year = row[0:4]
                month = row[4:6]
                day = row[6:8]
            elif len(str(row))==6:
                year = row[0:2]
                month = row[2:4]
                day = row[4:6]
                year = year.zfill(4)
                month = month.zfill(2)
                day = day.zfill(2)
                #print("short year when:" + row + " will be replace to" + year + month + day )
            elif len(str(row))==4:
                year = '0000'
                month = row[0:2]
                day = row[2:4]
                year = year.zfill(4)
                month = month.zfill(2)
                day = day.zfill(2)
                #print("year missing when:" + row + " will be replace to" + year + month + day )
            elif (len(str(row))> 8):
                year = row[0:4]
                month = row[4:6]
                day = row[6:8]
                year = year.zfill(4)
                month = month.zfill(2)
                day = day.zfill(2)
                #print("long data when:" + row + " will be replace to" + year + month + day )
            else:
                time = row.zfill(8)
                print("Cant fixed error when:" + row + " will be replace to" + row.zfill(8) )
            
            if int(month) > 12 or int(month) == 0:
                print("month over range: " + row + " " + month )
                #recheck
                print("month over range: " + row + " will be replace to "+row[-8:])
                time = row[-8:]
            else:
                year = year.zfill(4)
                month = month.zfill(2)
                day = day.zfill(2)
                time = year+month+day
                time = int(time)
                #time = datetime.datetime(year, month, day)
        elif pd.isnull(row)==True:
            #print("nan found")
            time = row
        else:
            print("unknow error when row is:" + row)
            time = row.zfill(8)
        temp.append(time)
    return temp

# %%
"1990".isdigit()
# Out:
# True

# %%
"1990-10-20"[9:10]
# Out:
# '0'

# %%
df['birthDate']=timemaker("birthDate")
# Out:
# Cant fixed error when:0430320 will be replace to00430320
# Cant fixed error when:2200429 will be replace to02200429
# Cant fixed error when:1060103 will be replace to01060103
# Cant fixed error when:1060103 will be replace to01060103
# month over range: 090819700908 19
# month over range: 090819700908 will be replace to 19700908
# Cant fixed error when:0701015 will be replace to00701015
# Cant fixed error when:1060103 will be replace to01060103
# Cant fixed error when:1060103 will be replace to01060103
# Cant fixed error when:0651208 will be replace to00651208

# %%
df['deathDate']=timemaker("deathDate")
# Out:
# Cant fixed error when:0431207 will be replace to00431207
# Cant fixed error when:0431207 will be replace to00431207
# Cant fixed error when:0190921 will be replace to00190921
# Cant fixed error when:0431207 will be replace to00431207
# Cant fixed error when:0431207 will be replace to00431207
# Cant fixed error when:0081127 will be replace to00081127

# %%
new_artic.to_csv('new_artic.csv')
